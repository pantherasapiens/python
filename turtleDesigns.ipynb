# %%
import turtle

# Create a turtle screen
wn = turtle.Screen()
wn.bgcolor("black")

# Create a turtle
spiral = turtle.Turtle()
spiral.speed(0)  # Set the drawing speed (0 is the fastest)

# Define colors for the spiral
colors = ["red", "orange", "yellow", "green", "blue", "purple"]

# Draw a colorful spiral
for i in range(360):
    spiral.color(colors[i % 6])  # Cycle through the colors
    spiral.forward(100)
    spiral.right(59)
    spiral.forward(100)
    spiral.right(59)
    spiral.forward(100)
    spiral.right(59)
    spiral.forward(100)
    spiral.right(59)
    spiral.forward(100)
    spiral.right(59)
    spiral.forward(100)
    spiral.right(59)

# Close the turtle graphics window when clicked
wn.exitonclick()

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.25.2

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
img1=np.zeros(shape=(600,800,3),dtype=np.int32)

cv2.rectangle(img1,pt1=(50,100),pt2=(150,250),color=(0,255,0),thickness=2)
plt.imshow(img1)

# %%
cv2.circle(img1,center=(50,50),radius=25,color=(255,255,255),thickness=-1)
plt.imshow(img1)

# %%
cv2.line(img1,pt1=(0,0),pt2=(600,800),color=(255,0,0),thickness=2)
plt.imshow(img1)

# %%
font=cv2.FONT_HERSHEY_PLAIN
# cv2.puttext(img2,text=('cuh'),org(300,300),fontFace=font,fontScale=3,color=(255,255,255),thickness=2)
# plt.imshow(img2)
# Out:
#   Cell In[2], line 2
#     cv2.puttext(img2,text=('cuh'),org(300,300),fontFace=font,fontScale=3,color=(255,255,255),thickness=2)
#                                                                                                         ^
# SyntaxError: positional argument follows keyword argument
